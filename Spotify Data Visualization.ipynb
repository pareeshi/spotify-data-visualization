# %%
# Simple data visualization with spotify genre data 
# Daniel Parisi, 2020

import pandas as pd

data_genre = pd.read_csv('data_by_genres.csv')

# Schemi utili:
# dataframe = pd.read_csv(‘file.csv’)
# dataframe = pd.read_csv(‘file.csv’, header=0, index_col=0, quotechar=’”’,sep=’:’, na_values = [‘na’, ‘-‘, ‘.’, ‘’])
# dataframe.to_csv(‘name.csv’, encoding=’utf-8')
# dictionary = dataframe.to_dict()
# string = dataframe.to_string()

# %%
data_genre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2664 entries, 0 to 2663
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   genres            2664 non-null   object
#  1   acousticness      2664 non-null   float64
#  2   danceability      2664 non-null   float64
#  3   duration_ms       2664 non-null   float64
#  4   energy            2664 non-null   float64
#  5   instrumentalness  2664 non-null   float64
#  6   liveness          2664 non-null   float64
#  7   loudness          2664 non-null   float64
#  8   speechiness       2664 non-null   float64
#  9   tempo             2664 non-null   float64
#  10  valence           2664 non-null   float64
#  11  popularity        2664 non-null   float64
#  12  key               2664 non-null   int64
#  13  mode              2664 non-null   int64
# dtypes: float64(11), int64(2), object(1)
# memory usage: 291.5+ KB

# %%
data_genre.head()
# Out:
#            genres  acousticness  danceability   duration_ms    energy  \
# 0           432hz      0.494780      0.299333  1.048887e+06  0.450678
# 1              []      0.679245      0.521473  2.298526e+05  0.401522
# 2      a cappella      0.621532      0.577017  1.936522e+05  0.345694
# 3        abstract      0.359395      0.459500  3.430185e+05  0.487000
# 4  abstract beats      0.353347      0.694400  2.338244e+05  0.613400
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0          0.477762  0.131000 -16.854000     0.076817  120.285667  0.221750
# 1          0.196737  0.221586 -12.679076     0.112267  112.025168  0.515920
# 2          0.003799  0.127087 -12.770211     0.095324  111.813230  0.453186
# 3          0.791400  0.119480 -14.092000     0.043420  124.743200  0.304990
# 4          0.349403  0.102453  -6.699800     0.143453  119.398400  0.634187
#
#    popularity  key  mode
# 0   52.166667    5     1
# 1   21.682005    7     1
# ...

# %%
data_genre.tail()
# Out:
#            genres  acousticness  danceability    duration_ms    energy  \
# 2659         zolo      0.218600      0.560365  267545.304878  0.611985
# 2660      zouglou      0.124000      0.834000  295147.000000  0.674000
# 2661         zouk      0.233181      0.752762  295109.952381  0.627238
# 2662  zouk riddim      0.052700      0.776000  229333.000000  0.656000
# 2663       zydeco      0.347767      0.596992  178837.901515  0.603610
#
#       instrumentalness  liveness   loudness  speechiness       tempo  \
# 2659          0.152665  0.190792 -11.499268     0.064295  123.283566
# 2660          0.000000  0.082800 -13.455000     0.072100  119.039000
# 2661          0.301195  0.083224 -10.864476     0.038110  101.681762
# 2662          0.565000  0.044500 -14.316000     0.034100   99.981000
# 2663          0.017112  0.230891  -9.831258     0.050168  129.441970
#
#        valence  popularity  key  mode
# 2659  0.596705   33.760410    9     1
# 2660  0.951000   56.000000    7     0
# ...

# %%
import numpy as np

import matplotlib.pyplot as plt

data_genre.hist(figsize = (20,20))
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(20,20))
sns.set(style = "whitegrid")
correlation = data_genre.corr()
sns.heatmap(correlation, annot = True)

# %%
#descrizione statistica: media, dev_standard, min-max, n/4 percentile

data_genre["acousticness"].describe()
print()
data_genre["danceability"].describe()
print()
data_genre["energy"].describe()
# Out:
# count    2664.000000
# mean        0.399060
# std         0.313948
# min         0.000003
# 25%         0.120052
# 50%         0.319612
# 75%         0.657829
# max         0.996000
# Name: acousticness, dtype: float64

# %%
most_acoustic_genres = data_genre[data_genre["acousticness"] > 0.75]["genres"]

# %%
sns.clustermap(correlation)
